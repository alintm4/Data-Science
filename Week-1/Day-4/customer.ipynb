# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cust=pd.read_csv("olist_customers_dataset.csv")
display(cust.head())
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
cust.customer_id
# Out:
# 0        06b8999e2fba1a1fbc88172c00ba8bc7
# 1        18955e83d337fd6b2def6b18a428ac77
# 2        4e7b3e00288586ebd08712fdd0374a03
# 3        b2b6027bc5c5109e529d4dc6358b12c3
# 4        4f2d8ab171c80ec8364f7c12e35b23ad
#                        ...
# 99436    17ddf5dd5d51696bb3d7c6291687be6f
# 99437    e7b71a9017aa05c9a7fd292d714858e8
# 99438    5e28dfe12db7fb50a4b2f691faecea5e
# 99439    56b18e2166679b8a959d72dd06da27f9
# 99440    274fa6071e5e17fe303b9748641082c8
# Name: customer_id, Length: 99441, dtype: object

# %%
cust[cust['customer_city']=='franca']
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 241    b9885472fa562ddc1cb5333a42b654fc  2767ebe1fedf70562aa588a37a23080a
# 650    5dca924cc99eea2dc5ba40d11ec5dd0f  2761fee7f378f0a8d7682d8a3fa07ab1
# 700    de3fa59dd658cd8b47a1634125047c01  fa87e5558d2010f19641ca49363d5a1a
# 1894   0489975a325480c9e385e9f135bb13c3  b577af9a54b023b4bcc51f69bb937f1c
# ...                                 ...                               ...
# 97420  e362750942a269ffb3be2aa866d81344  d47a6832268d7fb2d351d1dfc7f6efa2
# 98129  01edba0c1380aa0c91437bee4b7193a5  321606e7fd388f26b3a6ab005fa494f8
# 98847  250140565b02546b115981ac3442ed86  549038e2c41350e6ac5a9d601a93ceed
# 98852  a26d969df103529ca7d2dc3b8f8a1e5a  c1d17de7f48b64a544769023500456f0
# 99273  df0ec86a6c614ee79015aca7cb821316  a2fd4291f10d19ae29da6126c6f08ad0
#
#        customer_zip_code_prefix customer_city customer_state
# ...

# %%
cust.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
cust[['customer_city', 'customer_state']]
# Out:
#                customer_city customer_state
# 0                     franca             SP
# 1      sao bernardo do campo             SP
# 2                  sao paulo             SP
# 3            mogi das cruzes             SP
# 4                   campinas             SP
# ...                      ...            ...
# 99436              sao paulo             SP
# 99437        taboao da serra             SP
# 99438              fortaleza             CE
# 99439                 canoas             RS
# 99440                  cotia             SP
#
# [99441 rows x 2 columns]

# %%
#cust.loc[0:3, ['customer_city', 'customer_state']]  
cust.iloc[0:3, 1:4]
# Out:
#                  customer_unique_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
#
#            customer_city
# 0                 franca
# 1  sao bernardo do campo
# 2              sao paulo

# %%
cust.rename(columns={'customer_zip_code_prefix': 'zip_code'}, inplace=True)
cust
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        zip_code          customer_city customer_state
# ...

# %%
cust.sort_values(by='customer_city', ascending=True, inplace=True)
cust
# Out:
#                             customer_id                customer_unique_id  \
# 44027  a23e3f9a2b656b23b7e52075964b42cd  afddf43a03a9941624ed42c0b2c17280
# 74529  9e01f714a2b3b8962c222cf2b74c20dc  e1feae9083c4c2895ddf6dc80526a85d
# 19445  f11eb8f0b8b87510a93e3e1aa10b0ade  64ee476500a01beb94df40f97a108c50
# 42307  576d71ddb21b21763cfedce73b902180  8d76b559181609308fcae630ea64cd61
# 5205   5e9e1ae42e02df93e9a591e86fd531a3  28af9604f7830ef6d1230fb575c39eb1
# ...                                 ...                               ...
# 2121   1052e334b46dd1e9876946d6372a363e  c933181d09535cb6bdfb1c0160323bd9
# 89716  d8b3ef6f73de33ae716e94d2478cc080  9ef06526b8e57a567ed6f1dce7ab0320
# 51713  fc87e5c06780700952aa42998a22968f  d4798889fe74026a739ca0be9d2dccb8
# 53210  0a466d490a3c2fcc1e7177f4809ec7dd  d5a5ceb83234eeb855268d7fce7f54ea
# 7756   e046f992a304cc92e1b00d7fccdf1c42  09a3f87b74828b274d73ee9dfef43b68
#
#        zip_code        customer_city customer_state
# ...

# %%
cust.groupby('customer_state').size() 
#cust.groupby('customer_state')['zip_code'].nunique()
# Out:
# customer_state
# AC       81
# AL      413
# AM      148
# AP       68
# BA     3380
# CE     1336
# DF     2140
# ES     2033
# GO     2020
# MA      747
# MG    11635
# MS      715
# MT      907
# PA      975
# PB      536
# PE     1652
# PI      495
# PR     5045
# RJ    12852
# RN      485
# RO      253
# RR       46
# RS     5466
# SC     3637
# SE      350
# SP    41746
# TO      280
# dtype: int64

# %%
import matplotlib.pyplot as plt
cust['customer_city'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
cust['customer_state'].value_counts().plot(kind='pie')
plt.show()

# %%
top_cities = cust['customer_city'].value_counts().head(3)
print(top_cities)
display(cust)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# Name: count, dtype: int64
#                             customer_id                customer_unique_id  \
# 44027  a23e3f9a2b656b23b7e52075964b42cd  afddf43a03a9941624ed42c0b2c17280
# 74529  9e01f714a2b3b8962c222cf2b74c20dc  e1feae9083c4c2895ddf6dc80526a85d
# 19445  f11eb8f0b8b87510a93e3e1aa10b0ade  64ee476500a01beb94df40f97a108c50
# 42307  576d71ddb21b21763cfedce73b902180  8d76b559181609308fcae630ea64cd61
# 5205   5e9e1ae42e02df93e9a591e86fd531a3  28af9604f7830ef6d1230fb575c39eb1
# ...                                 ...                               ...
# 2121   1052e334b46dd1e9876946d6372a363e  c933181d09535cb6bdfb1c0160323bd9
# 89716  d8b3ef6f73de33ae716e94d2478cc080  9ef06526b8e57a567ed6f1dce7ab0320
# 51713  fc87e5c06780700952aa42998a22968f  d4798889fe74026a739ca0be9d2dccb8
# 53210  0a466d490a3c2fcc1e7177f4809ec7dd  d5a5ceb83234eeb855268d7fce7f54ea
# ...
