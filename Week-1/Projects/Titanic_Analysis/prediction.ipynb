# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('eda_titanic.csv')

# %%
class_survival = data.groupby('Pclass')['Survived'].mean()
print("\nSurvival rate by Pclass:")
print(class_survival)

data['AgeGroup'] = pd.cut(data['Age'], bins=[0, 12, 18, 30, 50, 80], 
                          labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])
age_survival = data.groupby('AgeGroup')['Survived'].mean()
print("\nSurvival rate by Age group:")
print(age_survival)

gender_survival = data.groupby('Sex')['Survived'].mean()
print("\nSurvival rate by Sex:")
print(gender_survival)
# Out:
# Survival rate by Pclass:
# Pclass
# 1    0.492063
# 2    0.351852
# 3    0.394366
# Name: Survived, dtype: float64
#
# Survival rate by Age group:
# AgeGroup
# Child          0.454545
# Teen           0.375000
# Young Adult    0.467742
# Adult          0.338462
# Senior         0.478261
# Name: Survived, dtype: float64
#
# Survival rate by Sex:
# Sex
# female    1.0
# male      0.0
# Name: Survived, dtype: float64
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12232\3940124909.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_survival = data.groupby('AgeGroup')['Survived'].mean()

# %%
sns.barplot(x=class_survival.index, y=class_survival.values)
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

sns.barplot(x=age_survival.index, y=age_survival.values)
plt.title('Survival Rate by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Survival Rate')
plt.show()

sns.barplot(x=gender_survival.index, y=gender_survival.values)
plt.title('Survival Rate by Sex')
plt.xlabel('Sex')
plt.ylabel('Survival Rate')
plt.show()
